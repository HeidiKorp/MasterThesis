# %%
import pandas as pd

# %%
data = pd.read_csv("../records/records_0-5000.csv")
data.head()
# Out:
#    Unnamed: 0  index  file_index  ObjectId  Flags  trackedByStationaryModel  \
# 0           0  22185     3758859         7    384                     False
# 1           1  22186     3759025         7    384                     False
# 2           2  22187     3759193         7    384                     False
# 3           3  22188     3759363         7    384                     False
# 4           4  22189     3759536         7    384                     False
#
#    mobile  motionModelValidated  ObjectAge     Timestamp  ...  uniqueId  \
# 0    True                     1         51  1.496307e+09  ...         3
# 1    True                     1         52  1.496307e+09  ...         3
# 2    True                     1         53  1.496307e+09  ...         3
# 3    True                     1         54  1.496307e+09  ...         3
# 4    True                     1         55  1.496307e+09  ...         3
#
#    origin  destination  relative_destination  AbsVelocity   distance  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'file_index', 'ObjectId', 'Flags',
#        'trackedByStationaryModel', 'mobile', 'motionModelValidated',
#        'ObjectAge', 'Timestamp', 'ObjectPredAge', 'Classification',
#        'ClassCertainty', 'ClassAge', 'ObjBoxCenter_X', 'ObjBoxCenter_Y',
#        'ObjBoxCenterSigma_X', 'ObjBoxCenterSigma_Y', 'ObjBoxSize_X',
#        'ObjBoxSize_Y', 'ObjCourseAngle', 'ObjCourseAngleSigma',
#        'ObjBoxOrientation', 'ObjBoxOrientationSigma', 'RelVelocity_X',
#        'RelVelocity_Y', 'RelVelocitySigma_X', 'RelVelocitySigma_Y',
#        'AbsVelocity_X', 'AbsVelocity_Y', 'AbsVelocitySigma_X',
#        'AbsVelocitySigma_Y', 'RefPointLocation', 'RefPointCoords_X',
#        'RefPointCoords_Y', 'RefPointCoordsSigma_X', 'RefPointCoordsSigma_Y',
#        'RefPointPosCorrCoeffs', 'ObjPriority', 'ObjExtMeasurement',
#        'EgoLatitude', 'EgoLongitude', 'EgoAltitude', 'EgoHeadingRad',
#        'EgoPosTimestamp', 'GPSFixStatus', 'csv_name', 'ObjPrediction',
# ...

# %%
X = data[['relative_x', 'relative_y', 'EgoHeadingRad', 'AbsVelocity']]
y = data['destination']

# %%
X.head()
# Out:
#    relative_x  relative_y  EgoHeadingRad  AbsVelocity  RelVelocity_X  \
# 0    -2.56309    -17.6780        5.52452     9.949961           9.66
# 1    -2.56242    -17.2906        5.52457     9.907970           9.66
# 2    -2.63978    -16.8482        5.52456    10.069128           9.80
# 3    -2.71399    -16.4184        5.52461    10.165674           9.89
# 4    -2.78626    -15.9888        5.52462    10.348175          10.06
#
#    RelVelocity_Y
# 0           2.38
# 1           2.20
# 2           2.31
# 3           2.36
# 4           2.44

# %%
y.head()
# Out:
# 0    south
# 1    south
# 2    south
# 3    south
# 4    south
# Name: destination, dtype: object

# %%
X.dtypes
# Out:
# relative_x       float64
# relative_y       float64
# EgoHeadingRad    float64
# AbsVelocity      float64
# RelVelocity_X    float64
# RelVelocity_Y    float64
# dtype: object
